# %% [markdown]
# <a href="https://colab.research.google.com/github/luanviccs/Diario.de.Evolucao/blob/main/cap1_part3_lab_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Processando a Informação: Cap. 1: Fundamentos - Prática 2

# %% [markdown]
# <img src="https://editora.ufabc.edu.br/images/Capa_Processando_Informacao.jpg" alt="Capa" width="150" align="right">
#
# ![]("figs/Capa_Processando_Informacao.jpg")
#
# Este caderno (*Notebook*) é uma parte complementar *online* do livro **[Processando a Informação](https://editora.ufabc.edu.br/matematica-e-ciencias-da-computacao/58-processando-a-informacao): um livro prático de programação independente de linguagem**, que deve ser consultado em caso de dúvidas sobre os temas apresentados.
#
# > Este conteúdo pode ser copiado e alterado livremente, sendo inspirado por este livro.

# %% [markdown]
# ### Exercícios
#
# [Fonte: https://wiki.python.org.br/EstruturaSequencial]

# %% [markdown]
# ---
# 1.   Faça um programa que peça o raio ($R$) de um círculo, calcule e mostre sua área ($\pi R^2$) e seu perímetro ($2\pi R$).

# %%
import math

raio = float(input("Digite o raio do círculo: "))
area = math.pi * raio ** 2
perimetro = 2 * math.pi * raio
print("A área do círculo é:", area)
print("O perímetro do círculo é:", perimetro)
# Out:
# Digite o raio do círculo: 5
# A área do círculo é: 78.53981633974483
# O perímetro do círculo é: 31.41592653589793

# %% [markdown]
# ---
#
# 2.   Faça um programa que peça a Apótema ($a$, ver figura), o número ($n$) de lados do polígono regular e o comprimento $l$ de cada lado. Calcule e mostre a sua Área ($A=nla/2$). Essa fórmula funciona para triângulo equilátero e quadrado? [[fonte](https://www.todamateria.com.br/area-dos-poligonos/amp/)]
# ![]("figs/poligono.png")

# %% [markdown]
# ![poligono.png](data:image/png;base64,...)

# %%
a = int(input("Digite o valor de A"))
b = int(input("Digite o valor de B"))
c = int(input("Digite o valor de C"))

if a > b:
    a, b = b, a

if a > c:
    a, c = c, a

if b > c:
    b, c = c, b

print(a, b, c)
# Out:
# Digite o valor de A10
# Digite o valor de B5
# Digite o valor de C3
# 3 5 10

# %% [markdown]
# ---
#
# 3.  Faça um programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.

# %%
temperatura_f = float(input("Digite a temperatura em Fahrenheit: "))
temperatura_c = (temperatura_f - 32) / 1.8

print(f"O resultado é {temperatura_c:.2f}")
# Out:
# Digite a temperatura em Fahrenheit: 75
# O resultado é 23.89

# %% [markdown]
# ---
#
# 4.   Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas por dia da semana (sem sábados e domingos). Calcule e mostre o total do seu salário semanal.

# %%
salario_hora = float(input("Digite o valor da sua hora de trabalho: "))
horas_trabalhadas_dia = int(input("Digite quantas horas você trabalha por dia: "))
dias_trabalhados = int(input("Digite quantos dias você trabalhou no mês: "))

if dias_trabalhados > 25:
    print("Atenção: O limite de dias úteis (25) foi excedido. Consideraremos apenas 25 dias.")
    dias_trabalhados = 25

salario_total = salario_hora * horas_trabalhadas_dia * dias_trabalhados

print(f"O total do seu salário é R$ {salario_total:.2f}")
# Out:
# Digite o valor da sua hora de trabalho: 65
# Digite quantas horas você trabalha por dia: 8
# Digite quantos dias você trabalhou no mês: 27
# Atenção: O limite de dias úteis (25) foi excedido. Consideraremos apenas 25 dias.
# O total do seu salário é R$ 13000.00

# %% [markdown]
# ---
#
# 5. Faça um programa que solicite 2 números inteiros e um número real. Calcule e exiba:
#   * o produto do dobro do primeiro com metade do segundo;
#   * a soma do triplo do primeiro com o terceiro;
#   * o terceiro elevado ao cubo.

# %%
numero_inteiro_1 = int(input("Digite o primeiro número inteiro: "))
numero_inteiro2 =  int(input("Digite o segundo número inteiro: "))
numero_real = float(input("Digite um número real: "))

resultado_1 = (numero_inteiro_1 * 2) * (numero_inteiro2 / 2)
resultado_2 = (numero_inteiro_1 * 3) + numero_real
resultado_3 = numero_real ** 3

print("O resultado do primeiro cálculo é:", resultado_1)
print("O resultado do segundo cálculo é:", resultado_2)
print("O resultado do terceiro cálculo é:", resultado_3)
# Out:
# Digite o primeiro número inteiro: 25
# Digite o segundo número inteiro: 14
# Digite um número real: 13.19
# O resultado do primeiro cálculo é: 350.0
# O resultado do segundo cálculo é: 88.19
# O resultado do terceiro cálculo é: 2294.7447589999997

# %% [markdown]
# ---
#
# 6. Tendo como dados de entrada a altura ($h$) de uma pessoa, construa um programa que calcule seu peso ideal, usando a seguinte fórmula:
# $$72.7h - 58$$

# %%
altura = float(input("Digite a altura (em metros): "))
peso_ideal = (72.7 * altura) - 58
print(f"O peso ideal para a altura {altura:.2f}m é: {peso_ideal:.2f} kg")
# Out:
# Digite a altura (em metros): 1.70
# O peso ideal para a altura 1.70m é: 65.59 kg

# %% [markdown]
# ---
#
# 7. Tendo como dado de entrada a altura ($h$) de uma pessoa, construa um programa que calcule seu peso ideal, utilizando as seguintes fórmulas:
#   * homens: $72.7h - 58$
#   * mulheres: $62.1h - 44.7$

# %%
altura = float(input("Digite a altura (em metros): "))
sexo = input("Digite o sexo (H para homem, M para mulher): ").upper()

if sexo == 'H':
    peso_ideal = (72.7 * altura) - 58
    print(f"O peso ideal para um homem com altura {altura:.2f}m é: {peso_ideal:.2f} kg")
elif sexo == 'M':
    peso_ideal = (62.1 * altura) - 44.7
    print(f"O peso ideal para uma mulher com altura {altura:.2f}m é: {peso_ideal:.2f} kg")
else:
    print("Sexo inválido. Por favor, digite 'H' para homem ou 'M' para mulher.")
# Out:
# Digite a altura (em metros): 1.75
# Digite o sexo (H para homem, M para mulher): M
# O peso ideal para uma mulher com altura 1.75m é: 63.97 kg

# %% [markdown]
# ---
#
# 8. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Considere que ele sempre traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos), neste caso, com uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Grave na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso_peixes = float(input("Digite o peso total de peixes (em quilos): "))
limite_peso = 50.0
valor_multa_por_quilo = 4.0

excesso = 0.0
multa = 0.0

if peso_peixes > limite_peso:
    excesso = peso_peixes - limite_peso
    multa = excesso * valor_multa_por_quilo

print(f"Peso de peixes: {peso_peixes:.2f} kg")
print(f"Excesso de peso: {excesso:.2f} kg")
print(f"Valor da multa a pagar: R$ {multa:.2f}")

# %% [markdown]
# ---
#
# 9. Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato. Faça um programa que forneça as seguintes informações:
#   * Salário bruto.
#   * Quanto pagou ao INSS.
#   * Quanto pagou ao sindicato.
#   * Salário líquido.
#
#   O programa deve calcular os descontos e o salário líquido, conforme a tabela abaixo:
#
# ```
#   + Salário Bruto : R$
#   - IR (11%) : R$
#   - INSS (8%) : R$
#   - Sindicato  (5%) : R$
#   = Salário Líquido : R$
# ```
#
# Obs.: Salário Bruto - Descontos = Salário Líquido

# %%
ganho_por_hora = float(input("Quanto você ganha por hora? R$"))
horas_trabalhadas_mes = float(input("Número de horas trabalhadas no mês: "))

salario_bruto = ganho_por_hora * horas_trabalhadas_mes

ir = salario_bruto * 0.11
inss = salario_bruto * 0.08
sindicato = salario_bruto * 0.05

salario_liquido = salario_bruto - ir - inss - sindicato

print(f"\n+ Salário Bruto : R$ {salario_bruto:.2f}")
print(f"- IR (11%) : R$ {ir:.2f}")
print(f"- INSS (8%) : R$ {inss:.2f}")
print(f"- Sindicato (5%) : R$ {sindicato:.2f}")
print(f"= Salário Líquido : R$ {salario_liquido:.2f}")

# %% [markdown]
# ---
#
# 10. Faça um programa para uma loja de tintas. O programa deve solicitar o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, custando R$ 80,00 cada. Informe ao usuário a quantidade de latas de tinta a serem compradas e o preço total.

# %%
import math

area_a_pintar = float(input("Digite o tamanho da área a ser pintada em metros quadrados: "))

litros_por_metro_quadrado = 1 / 3
litros_necessarios = area_a_pintar * litros_por_metro_quadrado

capacidade_lata = 18
preco_lata = 80.00

# Arredonda para cima para garantir que haja tinta suficiente
quantidade_latas = math.ceil(litros_necessarios / capacidade_lata)

preco_total = quantidade_latas * preco_lata

print(f"Você precisará comprar {quantidade_latas} lata(s) de tinta.")
print(f"O preço total será de R$ {preco_total:.2f}")
